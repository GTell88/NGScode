# %% [markdown]
# # Import Requirements

# %%
from __future__ import division
import pandas as pd
import numpy as np
from collections import Counter
import time
import statsmodels.api as sm
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Import data

# %%
sample_col = ['Patient','Visit']
demographics_col = ['Age', 'Gender', 'ART']
chemistry_col = ['VL','iVL','pVL','CD4','iCD4','nCD4','CD8','iCD8',u'nCD8']
neuro_col =['TMHDS','GDS']
sequence_col = ['Prot','AAPos','Coverage']
aa_col = ['A','R','N','D','C','Q','E','G','H','I','L','K','M','F','P','S','T','W','Y','V']

DF = pd.read_csv('/Users/greg/Desktop/FullNeuroIllumina/merged_data.csv')
DF.head()
# Out:
#   Patient Visit DateOfVisit  Age  Gender ART     VL     iVL     pVL   CD4  \
# 0   A0001   R09  2014-11-10   59    Male  on     20     987     987   797
# 1   A0010   R08  2014-11-12   59    Male  on     20      50     470  1167
# 2   A0013   R09  2014-11-10   68    Male  on     20     144   39373   771
# 3   A0019   R12  2015-02-02   46  Female  on     20      99  164020  1130
# 4   A0026   R09  2015-04-30   55    Male  on  67859  100000  100000   137
#
#      ...            L         K         M         F  P         S         T  \
# 0    ...     0.006934  0.001695  0.565052  0.000026  0  0.000848  0.000128
# 1    ...     0.005848  0.005848  0.584795  0.000000  0  0.000000  0.000000
# 2    ...     0.001661  0.004983  0.282392  0.000000  0  0.001661  0.000000
# 3    ...     0.008081  0.003367  0.526599  0.000000  0  0.001347  0.000673
# 4    ...     0.008982  0.000000  0.589820  0.000000  0  0.002994  0.000000
#
#           W  Y         V
# 0  0.416637  0  0.000205
# 1  0.403509  0  0.000000
# 2  0.209302  0  0.000000
# 3  0.452525  0  0.000000
# 4  0.389222  0  0.000000
#
# [5 rows x 57 columns]

# %% [markdown]
# # Define functions

# %%
def slice_position(df, pos):
    m = df['AAPos'] == pos
    sliced_df = df[m]
    return sliced_df

def chooseDataCols(pos_df):
    cols = []
    cols.extend(sample_col)
    cols.extend(neuro_col)
    cols.extend(aa_col)
    data = pos_df[cols].copy()
    data['intercept'] = 1.0
    return data

def filterX(X, threshold):
    t = X.max()>threshold
    #t = X.mean()>threshold
    filtered_cols = t[t==True].index.tolist()
    X = X[filtered_cols]
    return X

def getXandY(data, threshold):   
    train_cols = []
    train_cols.extend(aa_col)
    train_cols.extend(['intercept'])
    y = (data['GDS'] >= 0.5).astype(int)
    X = data[train_cols]
    X = filterX(X, threshold)
    return X, y

# %% [markdown]
# # One position example

# %%
pos_df = slice_position(DF,61)
data = chooseDataCols(pos_df)
X, y = getXandY(data, 0.05)
X = X*100
X['intercept'] = 1
# initialize and fit the model
logit = sm.Logit(y, X)
result = logit.fit()
print result.summary()
#print result.params
#print result.conf_int()
#for i,row in result.conf_int().iterrows():
#    print i,row[0],row[1]
# Out:
# Optimization terminated successfully.
#          Current function value: 0.508836
#          Iterations 12
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                    GDS   No. Observations:                   53
# Model:                          Logit   Df Residuals:                       45
# Method:                           MLE   Df Model:                            7
# Date:                Tue, 29 Mar 2016   Pseudo R-squ.:                  0.2657
# Time:                        21:24:01   Log-Likelihood:                -26.968
# converged:                       True   LL-Null:                       -36.727
#                                         LLR p-value:                  0.006710
# ==============================================================================
#                  coef    std err          z      P>|z|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# N              3.8777      1.921      2.018      0.044         0.112     7.643
# D              3.8833      1.912      2.031      0.042         0.135     7.632
# Q              4.1533      2.558      1.624      0.104        -0.861     9.167
# E              3.9851      2.037      1.956      0.050        -0.008     7.978
# G              3.9136      1.927      2.031      0.042         0.138     7.690
# H             15.1559      7.309      2.074      0.038         0.830    29.482
# S              3.9999      1.924      2.078      0.038         0.228     7.772
# intercept   -386.7703    190.208     -2.033      0.042      -759.572   -13.969
# ==============================================================================

# %% [markdown]
# # All positions

# %%
tat1_length=72
for i in range(1,tat1_length+1):
    #slice the data
    pos_df = slice_position(DF, i)
    
    # prep the data
    data = chooseDataCols(pos_df)
    X, y = getXandY(data,0.05)
    print (i, X.shape, y.shape)

    # initialize and fit the model
    try:
        logit = sm.Logit(y, X)
        result = logit.fit()
        print result.conf_int()
    except:
        continue
    print ''
# Out:
# (1, (54, 9), (54,))
# Optimization terminated successfully.
#          Current function value: 0.602671
#          Iterations 16
#                      0            1
# N         -2533.925134  4870.476837
# Q          -105.994948  1192.060960
# E          -155.741008   547.950677
# I          -149.924192   523.250377
# L          -713.813490   542.843303
# M          -141.388858   531.713963
# S          -149.159939   524.285749
# W          -150.132849   523.708645
# intercept  -523.069479   146.639008
#
# (2, (54, 11), (54,))
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: inf
#          Iterations: 35
# (3, (55, 5), (55,))
# Optimization terminated successfully.
#          Current function value: 0.672441
#          Iterations 7
#                     0           1
# Q         -214.729646  201.259176
# K         -242.417032  295.996764
# P         -212.734075  198.587698
# V         -217.173826  210.899370
# intercept -198.286303  211.818044
#
# (4, (55, 6), (55,))
# Optimization terminated successfully.
#          Current function value: 0.665133
#          Iterations 13
#                      0            1
# D           -84.809757    79.121894
# I           -88.696548    75.270283
# M         -1036.220040  1878.856994
# W         -1978.320197  1030.936445
# V           -88.451694    74.945772
# intercept   -73.623684    86.847855
#
# (5, (55, 6), (55,))
# Optimization terminated successfully.
#          Current function value: 0.637682
#          Iterations 10
#                     0           1
# N          -49.834662  133.664670
# D          -48.671190  136.532084
# E         -437.763256  283.255475
# P          -44.847343  143.774838
# S         -181.998630  841.831538
# intercept -133.552067   47.794236
#
# (6, (55, 5), (55,))
# Optimization terminated successfully.
#          Current function value: 0.638082
#          Iterations 15
#                      0            1
# R          -121.943799   138.655292
# Q         -1329.118114  7181.288847
# H          -518.364219   303.710006
# P          -124.929957   130.527916
# intercept  -129.216190   123.576560
#
# (7, (55, 7), (55,))
# Optimization terminated successfully.
#          Current function value: 0.613959
#          Iterations 9
#                     0           1
# R         -104.420152  244.869502
# N         -103.577088  247.327518
# L          -99.078106  243.007548
# K         -104.601305  242.720312
# S         -106.371492  242.359139
# V         -145.019672  341.752496
# intercept -242.051936  103.692436
#
# (8, (55, 5), (55,))
# Optimization terminated successfully.
#          Current function value: 0.658287
#          Iterations 11
#                     0           1
# D         -427.876176  548.394484
# E         -172.811569  184.415526
# I         -185.019396  175.037836
# L         -176.065534  177.918280
# intercept -177.043824  175.136041
#
# (9, (55, 7), (55,))
# Optimization terminated successfully.
#          Current function value: 0.633155
#          Iterations 12
#                      0            1
# A          -442.983188   228.695411
# D          -296.620687   532.061131
# E          -247.026687   340.268724
# H         -4116.926226  2926.579765
# K          -249.641974   339.186736
# P          -240.038868   345.146384
# intercept  -338.331446   246.384039
#
# (10, (55, 4), (55,))
# Optimization terminated successfully.
#          Current function value: 0.635640
#          Iterations 10
#                     0           1
# N          -91.869751  660.642588
# P          -19.018827  476.476022
# W          -14.161618  485.202980
# intercept -472.900362   18.820410
#
# (11, (54, 4), (54,))
# Optimization terminated successfully.
#          Current function value: 0.674018
#          Iterations 7
#                     0           1
# L         -129.100178  178.124476
# K         -116.233884  117.696157
# W         -120.598869  111.135318
# intercept -110.040586  119.159360
#
# (12, (54, 7), (54,))
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 1.244771
#          Iterations: 35
#                        0              1
# N            -565.935128     158.092322
# D          101894.024390  645532.929146
# Q           -1037.504298    1168.024663
# E            -631.069411     135.050152
# H               2.078572     607.976521
# K               0.534447     609.932030
# intercept    -601.371798       2.087309
#
# (13, (54, 3), (54,))
# Optimization terminated successfully.
#          Current function value: 0.678632
#          Iterations 5
#                     0           1
# H         -112.783952  115.773554
# P         -105.053964  121.894083
# intercept -114.218869  111.187494
#
# (14, (54, 4), (54,))
# Optimization terminated successfully.
#          Current function value: 0.670133
#          Iterations 13
#                      0            1
# G          -143.049174   128.760649
# P          -149.037051   122.759177
# W         -1221.153155  1377.895052
# intercept  -121.793444   147.777592
#
# (15, (54, 6), (54,))
# Optimization terminated successfully.
#          Current function value: 0.616180
#          Iterations 8
#                     0           1
# R         -169.629591  613.492294
# E         -125.270455  662.986834
# G         -151.731972  628.803462
# K         -164.268353  638.279643
# S         -147.022383  639.804674
# intercept -626.946487  151.273629
#
# (16, (54, 4), (54,))
# Optimization terminated successfully.
#          Current function value: 0.669955
#          Iterations 11
#                     0           1
# Q          -90.753221   74.389507
# H         -472.694642  592.417994
# S          -96.226184   67.674240
# intercept  -66.565784   94.557925
#
# (17, (54, 4), (54,))
# Optimization terminated successfully.
#          Current function value: 0.656593
#          Iterations 11
#                     0           1
# R         -214.394361  362.539235
# Q         -123.138939   69.252182
# P         -115.288283   77.439667
# intercept  -68.864671  121.876099
#
# (18, (55, 4), (55,))
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: inf
#          Iterations: 35
# (19, (55, 10), (55,))
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: inf
#          Iterations: 35
# (20, (55, 5), (55,))
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: inf
#          Iterations: 35
# (21, (55, 5), (55,))
# Optimization terminated successfully.
#          Current function value: 0.679051
#          Iterations 5
#                     0           1
# A         -102.599134   72.866605
# C          -96.997210   80.875704
# P         -101.974624   72.862053
# T         -125.283068   73.590405
# intercept  -72.400362  101.728864
#
# (22, (55, 5), (55,))
# Warning: Maximum number of iterations has been exceeded.
# /Users/greg/anaconda/lib/python2.7/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/greg/anaconda/lib/python2.7/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
#          Current function value: 0.665017
#          Iterations: 35
#                          0                1
# N            -32700.733517     32733.235411
# C              -107.515694        70.568622
# K         -18880951.839893  18881732.574282
# T              -113.252847        83.014642
# intercept       -69.898128       106.333397
#
# (23, (55, 5), (55,))
# Optimization terminated successfully.
#          Current function value: 0.620556
#          Iterations 10
#                     0            1
# N          -43.766116   421.673905
# K         -174.533916  1424.462548
# P         -225.378600   411.630667
# T          -42.242110   422.378806
# intercept -419.912161    42.435857
#
# (24, (55, 10), (55,))
# Optimization terminated successfully.
#          Current function value: 0.587378
#          Iterations 11
#                     0           1
# A         -270.846176  134.829645
# N         -272.041553  135.984815
# C         -261.079092  143.823734
# Q         -274.003689  153.044674
# H         -366.967809  147.798509
# K         -271.234027  134.665071
# P         -270.861133  133.864503
# S         -278.690328  128.413274
# T         -269.418596  134.919454
# intercept -134.234665  269.766031
#
# (25, (55, 3), (55,))
# Optimization terminated successfully.
#          Current function value: 0.654786
#          Iterations 7
#                     0           1
# C         -286.624781   44.290700
# Y         -287.794186   54.070397
# intercept  -43.869687  283.364520
#
# (26, (55, 5), (55,))
# Optimization terminated successfully.
#          Current function value: 0.659702
#          Iterations 15
#                      0            1
# C          -205.783246    81.278293
# F          -215.141785    72.133530
# T         -3383.252191  4493.305062
# Y          -213.347695    71.546352
# intercept   -71.246823   212.030629
#
# (27, (55, 4), (55,))
# Optimization terminated successfully.
#          Current function value: 0.657965
#          Iterations 7
#                     0           1
# C         -153.009439   45.660710
# K         -143.560083   57.051308
# Y         -159.297592   41.706979
# intercept  -45.248514  151.530624
#
# (28, (55, 4), (55,))
# Optimization terminated successfully.
#          Current function value: 0.655254
#          Iterations 14
#                      0            1
# R         -1701.149091  3687.041520
# Q          -462.041869   196.491036
# K          -136.868961    62.264075
# intercept   -61.723179   135.290644
#
# (29, (55, 9), (55,))
# Optimization terminated successfully.
#          Current function value: 0.601671
#          Iterations 19
#                      0            1
# R          -140.807713    80.519091
# C          -123.797916   107.188104
# Q          -140.233879    82.254543
# G         -4471.155462  7485.509343
# I          -799.897344   214.236674
# K          -140.110740    82.759784
# S          -167.904065    74.470001
# V          -161.019436    78.759762
# intercept   -81.789165   139.157392
#
# (30, (55, 2), (55,))
# Optimization terminated successfully.
#          Current function value: 0.692847
#          Iterations 4
#                    0          1
# C         -80.503144  71.077831
# intercept -69.941070  79.292902
#
# (31, (55, 4), (55,))
# Optimization terminated successfully.
#          Current function value: 0.642266
#          Iterations 12
#                      0           1
# C          -142.429430   48.334228
# F          -135.560916   94.651908
# Y         -2860.616196  655.583238
# intercept   -47.695604  141.187141
#
# (32, (55, 5), (55,))
# Optimization terminated successfully.
#          Current function value: 0.655494
#          Iterations 9
#                     0           1
# H         -205.233332  234.603883
# L         -194.369198   88.992819
# F         -195.727761   88.238318
# Y         -194.493953   88.474692
# intercept  -87.709531  193.766550
#
# (33, (55, 3), (55,))
# Optimization terminated successfully.
#          Current function value: 0.666765
#          Iterations 10
#                     0           1
# C         -171.752351  460.864949
# H          -61.688361  134.180409
# intercept -132.584249   60.890593
#
# (34, (55, 3), (55,))
# Optimization terminated successfully.
#          Current function value: 0.682475
#          Iterations 7
#                     0           1
# C         -119.401596   66.631144
# Y         -111.543156  105.866322
# intercept  -65.919298  118.076571
#
# (35, (55, 5), (55,))
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: inf
#          Iterations: 35
# (36, (55, 7), (55,))
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: inf
#          Iterations: 35
# (37, (55, 3), (55,))
# Optimization terminated successfully.
#          Current function value: 0.673349
#          Iterations 15
#                      0            1
# C           -70.229330   105.756149
# Y         -4664.756742  1976.861954
# intercept  -104.377023    69.663163
#
# (38, (55, 2), (55,))
# Optimization terminated successfully.
#          Current function value: 0.685603
#          Iterations 5
#                    0           1
# F          -60.70712  161.849861
# intercept -159.53231   59.889165
#
# (39, (55, 6), (55,))
# Optimization terminated successfully.
#          Current function value: 0.590825
#          Iterations 10
#                     0           1
# I          -26.457275  700.843815
# L          -22.336676  708.031142
# M          -24.441985  702.705828
# T          -26.584504  703.741591
# V          -24.991891  702.307615
# intercept -697.955717   26.278567
#
# (40, (55, 6), (55,))
# Optimization terminated successfully.
#          Current function value: 0.640518
#          Iterations 7
#                     0           1
# R          -69.658508  528.266514
# Q          -68.703882  533.267683
# K          -69.977185  532.060872
# S          -69.910701  527.480813
# T          -69.094927  528.715706
# intercept -527.460371   69.127485
#
# (41, (55, 2), (55,))
# Optimization terminated successfully.
#          Current function value: 0.671808
#          Iterations 5
#                     0           1
# K          -39.315097  273.655054
# intercept -270.347623   38.877523
#
# (42, (55, 4), (55,))
# Optimization terminated successfully.
#          Current function value: 0.660720
#          Iterations 6
#                     0           1
# A          -36.408705  198.275622
# G          -36.151115  198.760359
# S          -60.456230  195.466623
# intercept -196.960688   36.044491
#
# (43, (55, 2), (55,))
# Optimization terminated successfully.
#          Current function value: 0.692921
#          Iterations 4
#                     0           1
# L         -244.097159  224.579527
# intercept -222.618434  242.041470
#
# (44, (55, 4), (55,))
# Optimization terminated successfully.
#          Current function value: 0.638463
#          Iterations 10
#                     0           1
# R         -668.676794  629.069316
# G         -128.797227  472.630414
# S         -129.774466  471.890371
# intercept -468.997135  128.468691
#
# (45, (55, 3), (55,))
# Optimization terminated successfully.
#          Current function value: 0.654145
#          Iterations 11
#                      0           1
# H         -1202.348158  606.523675
# I          -136.655950  185.260027
# intercept  -183.137152  135.463019
#
# (46, (55, 3), (55,))
# Optimization terminated successfully.
#          Current function value: 0.636961
#          Iterations 11
#                     0           1
# L         -855.694275  792.063098
# S          -85.610954  586.595653
# intercept -582.520137   85.234110
#
# (47, (55, 3), (55,))
# Optimization terminated successfully.
#          Current function value: 0.628142
#          Iterations 13
#                      0           1
# L         -4151.987514  500.130103
# Y          -228.728230  182.151505
# intercept  -179.932302  227.165427
#
# (48, (55, 4), (55,))
# Optimization terminated successfully.
#          Current function value: 0.630202
#          Iterations 13
#                      0           1
# G          -107.160156  174.307980
# S          -132.351979  162.776884
# W         -3260.952003  993.662490
# intercept  -171.469366  106.092801
#
# (49, (55, 4), (55,))
# Optimization terminated successfully.
#          Current function value: 0.619855
#          Iterations 13
#                      0           1
# R          -140.522862   95.100755
# Q         -4436.133396  404.896959
# K          -135.250132   96.731156
# intercept   -93.044224  138.442054
#
# (50, (55, 3), (55,))
# Optimization terminated successfully.
#          Current function value: 0.640569
#          Iterations 10
#                      0           1
# E         -1261.433601  285.069744
# K          -118.556072  132.699285
# intercept  -130.301309  117.292572
#
# (51, (55, 3), (55,))
# Optimization terminated successfully.
#          Current function value: 0.668422
#          Iterations 7
#                     0           1
# E         -152.151395  114.873338
# K          -41.228863  103.674661
# intercept -101.239415   40.459881
#
# (52, (55, 5), (55,))
# Optimization terminated successfully.
#          Current function value: 0.628911
#          Iterations 14
#                      0            1
# A         -3968.435822  1368.523837
# R          -137.529992   219.079125
# Q          -134.741289   218.492735
# W          -141.367260   216.326972
# intercept  -216.796344   136.737664
#
# (53, (55, 6), (55,))
# Optimization terminated successfully.
#          Current function value: 0.543050
#          Iterations 14
#                      0            1
# R          -230.543118   463.542700
# E         -4657.601533  1393.351810
# G          -232.906520   461.604769
# K          -249.409498   456.773648
# S          -675.537391   351.284782
# intercept  -459.693681   232.286453
#
# (54, (55, 5), (55,))
# Optimization terminated successfully.
#          Current function value: 0.638960
#          Iterations 12
#                      0           1
# R           -63.964370  213.914294
# Q           -61.295987  198.437612
# K           -62.920857  196.425519
# P         -1049.649033  501.430686
# intercept  -196.425505   61.460951
#
# (55, (55, 5), (55,))
# Optimization terminated successfully.
#          Current function value: 0.623437
#          Iterations 18
#                      0            1
# A         -2080.354357  1057.570023
# R           -63.848931   170.998341
# Q           -65.902846   169.454960
# K         -8114.428617  2736.086894
# intercept  -169.860774    63.987851
#
# (56, (55, 4), (55,))
# Optimization terminated successfully.
#          Current function value: 0.613917
#          Iterations 13
#                      0            1
# R          -107.108204   591.095576
# Q          -108.944188   589.127882
# T         -4144.414576  1043.215977
# intercept  -588.641218   107.227819
#
# (57, (55, 5), (55,))
# Optimization terminated successfully.
#          Current function value: 0.662815
#          Iterations 14
#                     0           1
# R          -65.508358   94.940303
# G          -65.463137   95.722396
# K          -67.756015   92.305949
# T         -714.874345  804.028027
# intercept  -94.198460   65.191777
#
# (58, (55, 6), (55,))
# Optimization terminated successfully.
#          Current function value: 0.654555
#          Iterations 7
#                     0           1
# A         -317.895555  543.211539
# L         -299.241208  585.089750
# P         -317.066154  543.559042
# S         -315.907686  544.005814
# T         -317.012886  542.239451
# intercept -542.107529  316.692777
#
# (59, (53, 7), (53,))
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: inf
#          Iterations: 35
# (60, (53, 8), (53,))
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: inf
#          Iterations: 35
# (61, (53, 8), (53,))
# Optimization terminated successfully.
#          Current function value: 0.508836
#          Iterations 13
#                     0            1
# N           11.231651   764.307030
# D           13.494087   763.165063
# Q          -86.066123   916.732769
# E           -0.783022   797.793892
# G           13.752282   768.974950
# H           83.001186  2948.178482
# S           22.798094   777.174111
# intercept -759.571628   -13.968938
#
# (62, (53, 7), (53,))
# Optimization terminated successfully.
#          Current function value: 0.609054
#          Iterations 11
#                     0           1
# R         -319.308371  277.912038
# N          -87.309209  272.703653
# D         -124.030408  366.937530
# G          -87.319364  271.090552
# P          -98.018408  305.034151
# S          -84.925107  271.857897
# intercept -269.713905   85.751984
#
# (63, (53, 6), (53,))
# Optimization terminated successfully.
#          Current function value: 0.626598
#          Iterations 11
#                     0           1
# Q         -130.363317  578.575031
# E         -130.918933  578.037591
# K         -125.253639  583.556568
# P         -129.193279  579.345408
# S         -186.211321  705.689239
# intercept -575.758442  129.677424
#
# (64, (53, 9), (53,))
# Optimization terminated successfully.
#          Current function value: 0.609847
#          Iterations 29
#                       0             1
# A           -279.968100    752.558570
# N           -283.064954    747.521132
# H         -11238.925465   5699.643343
# I           -281.925108    754.103846
# K          -3374.858252  13907.656426
# P           -237.610992    788.007544
# S           -282.177924    754.145992
# T           -281.237170    750.299747
# intercept   -749.554173    280.462552
#
# (65, (54, 8), (54,))
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: inf
#          Iterations: 35
# (66, (54, 3), (54,))
# Optimization terminated successfully.
#          Current function value: 0.683511
#          Iterations 7
#                     0           1
# Q         -160.017988  208.041962
# H         -154.537478  234.739308
# intercept -206.628110  158.939855
#
# (67, (54, 10), (54,))
# Optimization terminated successfully.
#          Current function value: 0.590568
#          Iterations 12
#                     0           1
# A          -87.552068  234.503772
# N          -81.088124  249.681288
# D          -88.262842  232.548555
# Q         -350.184301  583.557183
# E          -83.296154  241.535494
# G          -85.577296  237.014591
# K         -167.132930  335.866473
# T          -82.902000  240.021044
# V          -86.419420  235.498113
# intercept -234.255938   86.344141
#
# (68, (54, 8), (54,))
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: inf
#          Iterations: 35
# (69, (55, 5), (55,))
# Optimization terminated successfully.
#          Current function value: 0.663968
#          Iterations 13
#                     0           1
# A         -305.888058  345.847932
# Q         -267.875245  310.853158
# L         -268.048593  289.932104
# P         -267.546129  291.221205
# intercept -289.245274  267.191145
#
# (70, (55, 5), (55,))
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.564757
#          Iterations: 35
#                         0               1
# L             -125.221650     4217.690318
# P              -13.045459      780.488538
# S              -11.553051      779.711353
# V         -8904989.041081  8905874.087247
# intercept     -777.501103       11.767825
#
# (71, (55, 4), (55,))
# Optimization terminated successfully.
#          Current function value: 0.656907
#          Iterations 11
#                     0           1
# E         -120.611827  222.583749
# K         -122.364099  222.300005
# S         -133.498621  292.593867
# intercept -220.252814  121.021860
#
# (72, (20, 7), (20,))
# Optimization terminated successfully.
#          Current function value: 0.416570
#          Iterations 33
#                       0             1
# R          -1159.864518   1973.949681
# Q          -1115.183087   1822.662703
# H          -1174.851213   1979.081019
# L          -1174.874552   1967.268537
# K         -13290.823902  25871.153635
# P          -1177.381301   1970.742692
# intercept  -1963.942392   1172.955825
# /Users/greg/anaconda/lib/python2.7/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
